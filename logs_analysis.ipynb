# %% [markdown]
# # Анализ логов

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, BooleanType, FloatType, DateType, TimestampType

from datetime import datetime
from pyspark.sql.functions import *

# !pip install pandas
import pandas as pd

# !pip install pyyaml ua-parser user-agents
from user_agents import parse
# библиотека для парсинга user-agent

# !pip install clickhouse_connect
import clickhouse_connect


# импорт модулей и библиотек
# Out:
# Requirement already satisfied: pandas in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from pandas) (1.24.0)
# Requirement already satisfied: six>=1.5 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyyaml in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (6.0)
# Requirement already satisfied: ua-parser in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (0.16.1)
# Requirement already satisfied: user-agents in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (2.2.0)
# Requirement already satisfied: clickhouse_connect in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (0.4.7)
# Requirement already satisfied: pytz in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from clickhouse_connect) (2022.1)
# Requirement already satisfied: requests in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from clickhouse_connect) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from requests->clickhouse_connect) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from requests->clickhouse_connect) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from requests->clickhouse_connect) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raspa\anaconda3\envs\py3103\lib\site-packages (from requests->clickhouse_connect) (2022.12.7)

# %%
spark = SparkSession \
    .builder \
    .appName("Log analysis") \
    .config("spark.driver.bindAddress","localhost") \
    .config("spark.ui.port","4040") \
    .getOrCreate()

# создание spark сессии

# %%
client_hostname = spark.read.csv('C:/Users/raspa/Desktop/data_ignore/client_hostname.csv', header=True)
# csv файл с данными клиентов

# %%
def edit_alias_list(str):
    if str == "[Errno 1] Unknown host":
        return "unknown"
    else:
        return str[2:len(str)-2]
    
    
def edit_address_list(str):
    if str == "null":
        return "unknown"
    elif str is None:
        return "unknown"
    else:
        return str[2:len(str)-2]
    
# функция для замены пропущенных значений и редактировании строк(очищает от скобок и кавычек в строке)

# %%
func_alias_list = udf(edit_alias_list, StringType())
func_address_list = udf(edit_address_list, StringType())

# %%
client_hostname = client_hostname.withColumn("alias_list_new", func_alias_list("alias_list"))
client_hostname = client_hostname.drop("alias_list")
client_hostname = client_hostname.withColumn("address_list_new", func_address_list("address_list"))
client_hostname = client_hostname.drop("address_list")

# %%
client_hostname = client_hostname.withColumnRenamed("alias_list_new", "alias_list")\
       .withColumnRenamed("address_list_new", "address_list")

# %%
logs = pd.read_table('C:/Users/raspa/Desktop/data_ignore/access.log', engine='python', header=None, 
                   names=["ip", "datetime", "request", "code_req", "port", "user_agent"], 
                   sep=" - - \[{1}(.+)\] \"(.*?)\" (\d+) (\d+) .+ \"(.{2,}?)\".*",  index_col=False)

# загрузка главного файла с данными
# первичная обработка с помощью RexEx

# %%
logs.head(5)
# Out:
#               ip             datetime  \
# 0   54.36.149.41  2019-01-22 03:56:14
# 1    31.56.96.51  2019-01-22 03:56:16
# 2    31.56.96.51  2019-01-22 03:56:16
# 3  40.77.167.129  2019-01-22 03:56:17
# 4    91.99.72.15  2019-01-22 03:56:17
#
#                                              request  code_req   port  \
# 0  GET /filter/27|13%20%D9%85%DA%AF%D8%A7%D9%BE%D...       200  30577
# 1     GET /image/60844/productModel/200x200 HTTP/1.1       200   5667
# 2     GET /image/61474/productModel/200x200 HTTP/1.1       200   5379
# 3     GET /image/14925/productModel/100x100 HTTP/1.1       200   1696
# 4  GET /product/31893/62100/%D8%B3%D8%B4%D9%88%D8...       200  41483
#
#                                           user_agent        browser   device
# 0  Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...      AhrefsBot   Spider
# 1  Mozilla/5.0 (Linux; Android 6.0; ALE-L21 Build...  Chrome Mobile   Huawei
# 2  Mozilla/5.0 (Linux; Android 6.0; ALE-L21 Build...  Chrome Mobile   Huawei
# 3  Mozilla/5.0 (compatible; bingbot/2.0; +http://...        bingbot   Spider
# 4  Mozilla/5.0 (Windows NT 6.2; Win64; x64; rv:16...        Firefox  Windows

# %%
logs.isnull().sum()

# проверка данных на пропущенные значения
# Out:
# ip            0
# datetime      0
# request       8
# code_req      0
# port          0
# user_agent    0
# browser       0
# device        0
# dtype: int64

# %%
logs.code_req = logs.code_req.fillna(0)
logs.port = logs.port.fillna(0)
logs.request = logs.request.fillna('unknown')
logs = logs.astype({"code_req": int, "port": int, "user_agent": str})


# замена пропущенных значений в столбцах на 0
# для конвертации в тип *integer*

# %%
format_date = '%d/%b/%Y:%H:%M:%S +0330'
format_date_now = '%Y-%m-%d %H:%M:%S'

# %%
logs.datetime = logs.datetime.apply(lambda x: datetime.strptime(x, format_date) if x is not(None) else datetime.strptime(str(datetime.now().replace(microsecond=0)), format_date_now))

# перевод даты из строки в формат datetime
# Out:
# CPU times: total: 10.7 s
# Wall time: 10.9 s

# %%
# %%time
logs["browser"] = logs.user_agent.apply(lambda x: parse(x).browser.family)

# вытащил из user-agent название браузера
# Out:
# CPU times: total: 10min 22s
# Wall time: 10min 24s

# %%
# %%time
logs["device"] = logs.user_agent.apply(lambda x: parse(x).device.brand if parse(x).device.brand is not(None) else parse(x).os.family)

# здесь вытащил бренд смартфона
# Out:
# CPU times: total: 13min 1s
# Wall time: 13min 1s

# %%
logs.show(5)

# %%
client = clickhouse_connect.get_client(host='localhost', username='default', password='0000')

# инициализация подключения к бд ClickHouse

# %%
client.command('CREATE DATABASE IF NOT EXISTS logs')

client.command('CREATE TABLE IF NOT EXISTS logs.log (ip String, datetime DateTime, request String, code_req Integer, port Integer, user_agent String, browser String, device String) ENGINE Memory')

# Создание БД и создание таблицы для загрузки датафрейма с логами
# Out:
# ''

# %%
client.insert('logs.log', logs, column_names=["ip", "datetime", "request", "code_req", "port", "user_agent", "browser", "device"]) 

# вставка данных в БД

# %%
result_2_3 = client.query("SELECT device, uniq(ip) AS count_users FROM logs.log GROUP BY device ORDER BY device").result_set
data_marts = pd.DataFrame(list(result_2_3), columns=['device_name', 'users_count'])

data_marts['percent_users'] = (data_marts['users_count']/data_marts['users_count'].sum())*100
# result_4

result_5 = client.query("SELECT device, count(request) AS cc FROM logs.log GROUP BY device ORDER BY device").result_set
result_5_df = pd.DataFrame(list(result_5), columns=['device_name', 'actions_device_count'])
data_marts = data_marts.merge(result_5_df)

data_marts['percent_actions'] = (data_marts['actions_device_count']/data_marts['actions_device_count'].sum())*100
# result_6

result_7 = client.query("SELECT browser, count(*) AS cc FROM logs.log GROUP BY browser ORDER BY cc DESC LIMIT 6").result_set
result_7_list = dict()
for device in data_marts.device_name:
    query = client.query("SELECT browser, count(*) AS cc FROM logs.log WHERE device = '"+device+"' GROUP BY browser ORDER BY cc DESC LIMIT 5").result_set
    query_dict = {}
    for y in range(len(query)):
        query_dict[query[y][0]] = query[y][1]
    result_7_list[device] = str(query_dict)
result_7_df = pd.DataFrame.from_dict(result_7_list, orient='index', columns=['top_browsers'])
result_7_df = result_7_df.reset_index(names='device_name')
data_marts = data_marts.merge(result_7_df)

result_8 = client.query("SELECT device, count(code_req) AS cc FROM logs.log WHERE code_req != 200 GROUP BY device ORDER BY device").result_set
result_8_df = pd.DataFrame(list(result_8), columns=['device_name', 'count_code_not_200'])
data_marts = data_marts.merge(result_8_df)

result_9 = client.query("SELECT device, groupArray(code_req) AS cc FROM logs.log WHERE code_req != 200 GROUP BY device ORDER BY device").result_set
result_9_list = list()
for x in range(len(result_9)):
    result_9_list.append((result_9[x][0], str(dict(pd.Series(result_9[x][1]).value_counts()))))
result_9_df = pd.DataFrame(result_9_list, columns=['device_name', 'count_code'])
data_marts = data_marts.merge(result_9_df)


# result_x = результат запроса в виде списка для пункта X в задании.

# %%
data_marts.to_csv('C:/Users/raspa/Desktop/data_marts_logs.csv')

# %%
data_marts
# Out:
#                device_name  users_count  percent_users  actions_device_count  \
# 0                     Acer           10       0.003709                   260
# 1                  Alcatel           52       0.019286                   975
# 2                   Amazon            3       0.001113                     4
# 3                    Apple        24981       9.265228                742618
# 4                   Archos            5       0.001854                    66
# 5                     Asus         1698       0.629773                 29717
# 6               BlackBerry           29       0.010756                   545
# 7                Chrome OS            6       0.002225                   347
# 8                    Cubot            1       0.000371                    80
# 9                   Fedora            6       0.002225                  1551
# 10                     Fly           13       0.004822                   163
# 11                 Generic         4153       1.540310                164894
# 12         Generic_Android         7493       2.779086                140895
# 13  Generic_Android_Tablet         1338       0.496252                 47864
# 14                Gigabyte            3       0.001113                    68
# 15                  Google           27       0.010014                   407
# 16                      HP            2       0.000742                   214
# 17                     HTC         3995       1.481710                 74023
# 18                  Huawei        36858      13.670300                555526
# 19                 Hyundai            9       0.003338                   188
# 20                 Infinix            1       0.000371                    53
# 21                      LG         9440       3.501211                164635
# 22                  Lenovo         2947       1.093016                 59081
# 23                   Linux          554       0.205474                 49356
# 24                  Mageia            1       0.000371                    49
# 25                Micromax          323       0.119798                  5022
# 26               Microsoft           23       0.008530                  1302
# 27                Motorola          284       0.105333                  3172
# 28                   Nokia         1997       0.740669                 38481
# 29                 OnePlus          104       0.038573                  1208
# 30                    Oppo           29       0.010756                   333
# 31                   Other         1610       0.597134                 47114
# 32                     POV            1       0.000371                     1
# 33               Prestigio           19       0.007047                   565
# 34                     RCA            1       0.000371                    35
# 35                 Samsung       116652      43.265176               1844703
# 36                 Solaris            1       0.000371                     2
# 37                    Sony         4574       1.696455                 78336
# 38            SonyEricsson         1062       0.393886                 14803
# 39                  Spider         3503       1.299231               1109333
# 40                   Tecno          230       0.085305                  2260
# 41                Trekstor            2       0.000742                    44
# 42                  Ubuntu          135       0.050070                  5503
# 43                 Windows        41363      15.341164               5121900
# 44                  XiaoMi         3806       1.411611                 54331
# 45                     ZTE          147       0.054521                  2346
# 46                     iOS           31       0.011498                    61
# 47                    vivo           18       0.006676                   179
#
#     percent_actions                                       top_browsers  \
# 0          0.002508  {'Chrome': 223, 'Android': 33, 'Chrome Mobile ...
# 1          0.009407  {'Android': 568, 'Chrome Mobile': 279, 'Chrome...
# 2          0.000039                                 {'Amazon Silk': 4}
# 3          7.164564  {'Mobile Safari': 441761, 'Chrome Mobile iOS':...
# 4          0.000637                                    {'Android': 66}
# 5          0.286701  {'Chrome Mobile': 20691, 'Chrome': 3319, 'Chro...
# 6          0.005258                         {'BlackBerry WebKit': 545}
# 7          0.003348                                    {'Chrome': 347}
# 8          0.000772                              {'Chrome Mobile': 80}
# 9          0.014964                   {'Firefox': 1293, 'Chrome': 258}
# 10         0.001573  {'Chrome Mobile': 117, 'Android': 35, 'Chrome ...
# 11         1.590850  {'Firefox Mobile': 162622, 'Chrome Mobile': 11...
# 12         1.359314  {'Chrome Mobile': 114181, 'Chrome Mobile WebVi...
# 13         0.461778  {'Chrome': 45214, 'Chrome Mobile WebView': 229...
# 14         0.000656                {'Chrome Mobile': 64, 'Android': 4}
# 15         0.003927  {'Chrome Mobile': 227, 'Chrome Mobile WebView'...
# 16         0.002065                     {'Chrome': 119, 'Android': 95}
# 17         0.714153  {'Chrome Mobile': 53924, 'Android': 9758, 'Chr...
# 18         5.359555  {'Chrome Mobile': 377623, 'Android': 123574, '...
# 19         0.001814  {'Chrome Mobile WebView': 98, 'Chrome': 53, 'C...
# 20         0.000511                              {'Chrome Mobile': 53}
# 21         1.588351  {'Chrome Mobile': 132506, 'Chrome Mobile WebVi...
# 22         0.569996  {'Chrome': 39918, 'Android': 8112, 'Chrome Mob...
# 23         0.476172  {'Chrome': 42988, 'Samsung Internet': 2703, 'O...
# 24         0.000473                                    {'Firefox': 49}
# 25         0.048451  {'Chrome': 4089, 'Android': 531, 'Chrome Mobil...
# 26         0.012561                                {'IE Mobile': 1302}
# 27         0.030603  {'Chrome Mobile': 2663, 'Android': 360, 'Chrom...
# 28         0.371254  {'Chrome Mobile': 27950, 'Edge Mobile': 4699, ...
# 29         0.011654  {'Chrome Mobile': 1034, 'Android': 130, 'Opera...
# 30         0.003213  {'Chrome Mobile': 236, 'Opera Mobile': 72, 'An...
# 31         0.454542  {'Other': 42296, 'okhttp': 2365, 'curl': 1336,...
# 32         0.000010                       {'Chrome Mobile WebView': 1}
# 33         0.005451  {'Android': 451, 'Chrome': 111, 'Chrome Mobile...
# 34         0.000338                                     {'Chrome': 35}
# 35        17.797163  {'Chrome Mobile': 904881, 'Samsung Internet': ...
# 36         0.000019                                       {'Other': 2}
# 37         0.755763  {'Chrome Mobile': 67249, 'Android': 7842, 'Chr...
# 38         0.142815  {'Chrome Mobile': 9123, 'Android': 5066, 'Chro...
# 39        10.702525  {'Googlebot': 642679, 'bingbot': 200700, 'Goog...
# 40         0.021804  {'Chrome Mobile': 1795, 'Android': 287, 'Chrom...
# 41         0.000424        {'Chrome Mobile WebView': 43, 'Android': 1}
# 42         0.053091  {'Firefox': 4298, 'Chromium': 1143, 'pingbot':...
# 43        49.414615  {'Chrome': 2717885, 'Firefox': 2085389, 'IE': ...
# 44         0.524170  {'Chrome Mobile': 39485, 'MiuiBrowser': 7925, ...
